# %%
import pandas as pd
import numpy as np
import os
from scipy import optimize
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %% [markdown]
# # Data curation

# %%
#  define the exponential function
def func(time,a,kobs):
    return a*(1-np.exp(-kobs*time))

# %%
file_path = './CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25degC_rep1.txt'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit

# Sample data (replace this with your actual data)
t = np.linspace(0, 10, 50)  # time points
F = 10 * (1 - np.exp(-0.5 * t)) + np.random.normal(0, 0.5, size=t.size)  # fluorescence data with noise

# Define the fitting function
def func(time, a, kobs):
    return a * (1 - np.exp(-kobs * time))

# %%
def file_to_data(file_path,trim=(0,-1)):
    
    # Define the regular expression pattern
    pattern = r'Di_(\d+)uM_Di_4GF_(\d+)uM_(\d+)degC_rep(\d+)'

    # Find all numbers in the string using regex
    match = re.findall(pattern, file_path)

    match = match[0]

    # Check if a match is found
    if match:
        # Extract numbers from groups
        conc_Di = int(match[0])
        conc_DiF = int(match[1])
        temp = int(match[2])
        rep = int(match[3])

        # Print the numbers
        print(f"The concentration of CC-Di was: {conc_Di}")
        print(f"The concentration of labelled CC-Di was: {conc_DiF}")
        print(f"The temperature was: {temp}°C")
        print(f"The is replicate number: {rep}")
        print(f"Reading file at: {file_path}")
        
        # Read raw data
        df = pd.read_csv(file_path,
                    delimiter='\t',
                    header=None,
                    skiprows=18)
        #  Add column headers
        df.columns=['t','F']
        df['temp']=temp
        df['concDi']=conc_Di
        df['concDiF']=conc_DiF
        df['rep']=rep
        df['filepath']=file_path

    else:
        print("No match found.")
        df = None
        
    if df.empty:
        print("No data")
    else:
        xdata=df['t']
        ydata=df['F']
        
        plt.figure(0,(6,5))
        plt.title(f"{conc_Di}uM CC-Di with {conc_DiF}uM CC-DiF,\nat {temp}°C, rep {rep},\nin PBS at pH 7.4",fontsize=8)
        plt.plot(xdata,ydata)
        plt.set_ylabel('Raw Fluorescence (A.U.)')
        plt.set_xlabel('Time (secs)')
        plt.axvline(xdata[trim[0]],c='orange')
        plt.axvline(xdata[len(xdata)+trim[1]],c='orange')
        plt.legend(labels=['Data'])
        
        figpath= file_path.replace('.txt','_trimmed_data.png')
        print(f"Saving plot to: {figpath}")

        plt.savefig(figpath)
    
        plt.show()
        
        
        
        df=df.iloc[trim[0]:trim[1],:]
        #normalise fluorescence
        df.loc[:, 'Fnrm'] = (df['F'] - df['F'].min()) / (df['F'].max() - df['F'].min())
        #normalise time such that the first time point is 0 seconds
        df.loc[:, 't0'] = df['t'] - df['t'].min()

        xdata=df['t0']
        ydata=df['Fnrm']

        popt, pcov = curve_fit(func, xdata, ydata,p0=[1,1])

        t = np.arange(0.0,max(xdata),0.001)
        new_value = func(t, popt[0],popt[1])
        val = func(xdata, popt[0],popt[1])

        rate = popt[1]
        half_life=(np.log(2)/popt[1])
        r2_fit = r2_score(ydata, val)


        residuals_fit = func(xdata, popt[0],popt[1])
        residuals = ydata-residuals_fit

        plt.clf()
        
        # Set up the figure with two subplots
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), gridspec_kw={'height_ratios': [3, 1]})
        
        # Plot the data and fit on the main plot (ax1)
        ax1.set_ylabel('Normalised Fluorescence (A.U.)')
        ax1.legend()
        ax1.set_title(f"{conc_Di}uM CC-Di with {conc_DiF}uM CC-DiF,\nat {temp}°C, rep {rep},\nin PBS at pH 7.4",fontsize=8)
        ax1.plot(xdata,ydata)
        ax1.plot(t,new_value)
        ax1.legend(labels=['Data','Fit'])
        fit_data_string = (fr"rate = {np.round(rate, 6)} $s^{{-1}}$" + "\n" +
                   fr"half life = {np.round(half_life, 1)} $s^{{-1}}$" + "\n" +
                   fr"$R^2$ fit = {np.round(r2_fit, 3)}")
        ax1.annotate(fit_data_string, xy=(0.7,0.05), xycoords='axes fraction')

        data = {'temp':temp,
                'concDi':conc_Di,
                'concDiF':conc_DiF,
                'rep':rep,
                'filepath':file_path,
                'rate':rate,
                'halflife':half_life,
                'r2':r2_fit,
                'rmv from start':trim[0],
                'rmv from end':trim[1],
        }
        
        ax2.plot(xdata,residuals)
        ax2.axhline(0, color='gray', linestyle='--')  # Line at zero for reference
        ax2.set_ylabel('Residuals')
        ax2.set_xlabel('Time (secs)')        
        figpath= file_path.replace('txt','png')
        
        print(f"Saving plot to: {figpath}")
        data['figpath']=figpath

        plt.savefig(figpath)
    
        plt.show()
        
        return df, data

# %%
def find_txt_files(folder):
    txt_files = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if file.endswith(".txt"):
                txt_files.append(os.path.join(root, file))
    return txt_files

folder_path = "./CCDi_data/Ratios_const_labelled/"
txt_files = find_txt_files(folder_path)

# %%
txt_files
# Out:
# ['./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/0_2/CCDi_0uM_CCDi4GF_2uM_PBS_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep1.txt']

# %%
df, data= file_to_data(txt_files[0],
            trim=(113,-500))
# Out:
# The concentration of CC-Di was: 200
# The concentration of labelled CC-Di was: 2
# The temperature was: 25°C
# The is replicate number: 2
# Reading file at: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep2.txt
# Saving plot to: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep2_trimmed_data.png
# /Users/phr361/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/k0/7lzlp98x6c188pkk0rzbn2d40000gn/T/ipykernel_91000/71428140.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# Saving plot to: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep2.png

# %%
master_df = df.copy()

master_dict = [data.copy()]

# %%
txt_files
# Out:
# ['./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/100_2/Di_100uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/30_2/Di_30uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/0_2/CCDi_0uM_CCDi4GF_2uM_PBS_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/20_2/Di_20uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/10_2/Di_10uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/5_2/Di_5uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/50_2/Di_50uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/1_2/Di_1uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_labelled/2_2/Di_2uM_Di_4GF_2uM_25degC_rep1.txt']

# %%
df, data= file_to_data(txt_files[2],
            trim=(85,-4500))
# Out:
# The concentration of CC-Di was: 200
# The concentration of labelled CC-Di was: 2
# The temperature was: 25°C
# The is replicate number: 1
# Reading file at: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep1.txt
# Saving plot to: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep1_trimmed_data.png
# /Users/phr361/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /var/folders/k0/7lzlp98x6c188pkk0rzbn2d40000gn/T/ipykernel_91000/71428140.py:95: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
# Saving plot to: ./CCDi_data/Ratios_const_labelled/200_2/Di_200uM_Di_4GF_2uM_25degC_rep1.png

# %%
master_df = pd.concat([master_df,df],ignore_index=True)

master_dict.append(data)

# %%
master_df.to_excel('df_const_CCDiF.xlsx')

# %%
df_rates=pd.DataFrame(master_dict)

# %%
df_rates
# Out:
#     temp  concDi  concDiF  rep  \
# 0     25     200        2    2
# 1     25     200        2    3
# 2     25     200        2    1
# 3     25     100        2    1
# 4     25     100        2    3
# 5     25     100        2    2
# 6     25      30        2    2
# 7     25      30        2    3
# 8     25      30        2    1
# 9     25      20        2    1
# 10    25      20        2    3
# 11    25      20        2    2
# 12    25      10        2    1
# 13    25      10        2    3
# 14    25      10        2    2
# 15    25       5        2    2
# 16    25       5        2    3
# 17    25       5        2    1
# 18    25      50        2    1
# 19    25      50        2    3
# 20    25      50        2    2
# 21    25       1        2    1
# 22    25       2        2    2
# 23    25       2        2    3
# 24    25       2        2    1
#
#                                              filepath      rate     halflife  \
# 0   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...  0.002663   260.316502
# 1   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...  0.002745   252.506268
# 2   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...  0.002442   283.864497
# 3   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...  0.001586   437.127623
# 4   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...  0.001917   361.592422
# 5   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...  0.001968   352.227880
# 6   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...  0.001050   660.016444
# 7   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...  0.001101   629.666376
# 8   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...  0.001120   619.135954
# 9   ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...  0.001044   663.797951
# 10  ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...  0.001077   643.684297
# 11  ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...  0.001131   613.044731
# 12  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...  0.000967   717.065883
# 13  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...  0.000785   882.531464
# 14  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...  0.000813   852.461450
# 15  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...  0.000917   755.836183
# 16  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...  0.000670  1034.935674
# 17  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...  0.001143   606.433731
# 18  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...  0.001408   492.449796
# 19  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...  0.001537   450.881978
# 20  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...  0.001403   494.012594
# 21  ./CCDi_data/Ratios/1_2/Di_1uM_Di_4GF_2uM_25deg...  0.001993   347.730483
# 22  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...  0.000574  1206.543311
# 23  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...  0.000896   773.951593
# 24  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...  0.001176   589.252002
#
#           r2  rmv from start  rmv from end  \
# 0   0.993643             113          -500
# 1   0.999489              56            -1
# 2   0.993172              85         -4500
# 3   0.996571             155            -1
# 4   0.999678             154            -1
# 5   0.989457             220            -1
# 6   0.996162              80            -1
# 7   0.996186             110            -1
# 8   0.997861              90            -1
# 9   0.998184              90            -1
# 10  0.995379             120            -1
# 11  0.995737             110         -3500
# 12  0.989266              80            -1
# 13  0.998846             120            -1
# 14  0.997836             100            -1
# 15  0.995898              82            -1
# 16  0.980593             120            -1
# 17  0.983591             120            -1
# 18  0.998252              80            -1
# 19  0.998766             330            -1
# 20  0.988547             120            -1
# 21  0.975090              70          -250
# 22  0.995059              70          -250
# 23  0.996587              90         -1000
# 24  0.952280              90            -1
#
#                                               figpath
# 0   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...
# 1   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...
# 2   ./CCDi_data/Ratios/200_2/Di_200uM_Di_4GF_2uM_2...
# 3   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...
# 4   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...
# 5   ./CCDi_data/Ratios/100_2/Di_100uM_Di_4GF_2uM_2...
# 6   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...
# 7   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...
# 8   ./CCDi_data/Ratios/30_2/Di_30uM_Di_4GF_2uM_25d...
# 9   ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...
# 10  ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...
# 11  ./CCDi_data/Ratios/20_2/Di_20uM_Di_4GF_2uM_25d...
# 12  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...
# 13  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...
# 14  ./CCDi_data/Ratios/10_2/Di_10uM_Di_4GF_2uM_25d...
# 15  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...
# 16  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...
# 17  ./CCDi_data/Ratios/5_2/Di_5uM_Di_4GF_2uM_25deg...
# 18  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...
# 19  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...
# 20  ./CCDi_data/Ratios/50_2/Di_50uM_Di_4GF_2uM_25d...
# 21  ./CCDi_data/Ratios/1_2/Di_1uM_Di_4GF_2uM_25deg...
# 22  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...
# 23  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...
# 24  ./CCDi_data/Ratios/2_2/Di_2uM_Di_4GF_2uM_25deg...

# %%
df_rates = df_rates.drop(index=21)

# %%
df_rates['concDiM']=df_rates['concDi']/1000000

# %%
df_rates.to_excel('df_rates_constant_CCDiF.xlsx')

# %%
folder_path = "./CCDi_data/Ratios_const_unlabelled/"
txt_files = find_txt_files(folder_path)

# %%
df, data= file_to_data(txt_files[0],
            trim=(88,-1))
# Out:
# The concentration of CC-Di was: 200
# The concentration of labelled CC-Di was: 1
# The temperature was: 25°C
# The is replicate number: 2
# Reading file at: ./CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep2.txt
# Saving plot to: ./CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep2_trimmed_data.png
# /Users/phr361/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Saving plot to: ./CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep2.png

# %%
master_df_constant_CCDi = df.copy()

master_dict_constant_CCDi = [data.copy()]

# %%
txt_files
# Out:
# ['./CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_1uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_5uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_5uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_5uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_2uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_2uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_2uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_10uM_25degC_rep1.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_10uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_10uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_20uM_25degC_rep2.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_20uM_25degC_rep3.txt',
#  './CCDi_data/Ratios_const_unlabelled/Di_200uM_Di_4GF_20uM_25degC_rep1.txt']

# %%
df, data= file_to_data(txt_files[15],
            trim=(105,-1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[485], line 1
# ----> 1 df, data= file_to_data(txt_files[15],
#       2             trim=(105,-1))
#
# IndexError: list index out of range

# %%
master_df_constant_CCDi = pd.concat([master_df_constant_CCDi,df],ignore_index=True)

master_dict_constant_CCDi.append(data)

# %%
master_df_constant_CCDi.to_excel('master_df_constant_CCDi.xlsx')

# %%
df_rates_constant_CCDi=pd.DataFrame(master_dict_constant_CCDi)

# %%
df_rates_constant_CCDi.to_excel('df_rates_constant_CCDi.xlsx')

# %%
df_rates_constant_CCDi
# Out:
#     temp  concDi  concDiF  rep  \
# 0     25     200        1    2
# 1     25     200        1    3
# 2     25     200        1    1
# 3     25     200        5    1
# 4     25     200        5    2
# 5     25     200        5    3
# 6     25     200        2    2
# 7     25     200        2    3
# 8     25     200        2    1
# 9     25     200       10    1
# 10    25     200       10    3
# 11    25     200       10    2
# 12    25     200       20    2
# 13    25     200       20    3
# 14    25     200       20    1
#
#                                              filepath      rate    halflife  \
# 0   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002653  261.255894
# 1   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002838  244.207218
# 2   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002445  283.533971
# 3   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002523  274.712704
# 4   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002766  250.623810
# 5   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002768  250.457331
# 6   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002663  260.316502
# 7   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002745  252.506268
# 8   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002442  283.864497
# 9   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002507  276.488302
# 10  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002911  238.089544
# 11  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002980  232.574690
# 12  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.002848  243.404706
# 13  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.003201  216.569902
# 14  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...  0.003290  210.700178
#
#           r2  rmv from start  rmv from end  \
# 0   0.991459              88            -1
# 1   0.999934             100          -100
# 2   0.999514             122            -1
# 3   0.997231              92            -1
# 4   0.999655              88          -700
# 5   0.999839              70            -1
# 6   0.993643             113          -500
# 7   0.999489              56            -1
# 8   0.993172              85         -4500
# 9   0.996912             100            -1
# 10  0.999927              80            -1
# 11  0.999943              88            -1
# 12  0.987246              75            -1
# 13  0.999974              70          -150
# 14  0.997526             105            -1
#
#                                               figpath
# 0   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 1   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 2   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 3   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 4   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 5   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 6   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 7   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 8   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 9   ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 10  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 11  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 12  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 13  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...
# 14  ./CCDi_data/Ratios_const_unlabelled/Di_200uM_D...

# %%
folder_path = "./CCDi_data/Arhenius_files/"
txt_files = find_txt_files(folder_path)

# %%
txt_files
# Out:
# ['./CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep1.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep2.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep3.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_40degC_rep3.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_40degC_rep2.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_40degC_rep1.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_37degC_rep1.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_37degC_rep2.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_37degC_rep3.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_28degC_rep2.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_28degC_rep3.txt',
#  './CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_28degC_rep1.txt']

# %%
df, data= file_to_data(txt_files[0],
            trim=(80,-1))
# Out:
# The concentration of CC-Di was: 20
# The concentration of labelled CC-Di was: 2
# The temperature was: 32°C
# The is replicate number: 1
# Reading file at: ./CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep1.txt
# Saving plot to: ./CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep1_trimmed_data.png
# /Users/phr361/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Saving plot to: ./CCDi_data/Arhenius_files/Di_20uM_Di_4GF_2uM_32degC_rep1.png

# %%
master_df_varTemp = df.copy()

master_dict_varTemp = [data.copy()]

# %%
df, data= file_to_data(txt_files[12],
            trim=(100,-1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[576], line 1
# ----> 1 df, data= file_to_data(txt_files[12],
#       2             trim=(100,-1))
#
# IndexError: list index out of range

# %%
master_df_varTemp = pd.concat([master_df_varTemp,df],ignore_index=True)

master_dict_varTemp.append(data)

# %%
df_rates_varTemp=pd.DataFrame(master_dict_varTemp)

# %%
master_df_varTemp = pd.concat([master_df_varTemp,
                               master_df[master_df['concDi']==20]],
                              ignore_index=True)
df_rates_varTemp = pd.concat([df_rates_varTemp,
                               df_rates[df_rates['concDi']==20]],
                              ignore_index=True)

# %%
master_df_varTemp.to_excel('master_df_varTemp.xlsx')
df_rates_varTemp.to_excel('df_rates_varTemp.xlsx')
